# %%
import numpy as np
import h5py
from loading_data import get_optical_depth

# %%
z = 2
optical_depth_z2 = get_optical_depth(z, 250)
# Out:
# File loaded: /disks/cosmodm/maria/lyman_alpha/z_2/spectra_H_He_only_z2_250_spectra_0_part.hdf5
# File loaded: /disks/cosmodm/maria/lyman_alpha/z_2/spectra_H_He_only_z2_250_spectra_10_part.hdf5
# File loaded: /disks/cosmodm/maria/lyman_alpha/z_2/spectra_H_He_only_z2_250_spectra_11_part.hdf5
# File loaded: /disks/cosmodm/maria/lyman_alpha/z_2/spectra_H_He_only_z2_250_spectra_12_part.hdf5
# File loaded: /disks/cosmodm/maria/lyman_alpha/z_2/spectra_H_He_only_z2_250_spectra_13_part.hdf5
# File loaded: /disks/cosmodm/maria/lyman_alpha/z_2/spectra_H_He_only_z2_250_spectra_14_part.hdf5
# File loaded: /disks/cosmodm/maria/lyman_alpha/z_2/spectra_H_He_only_z2_250_spectra_15_part.hdf5
# File skipped/corrupted: /disks/cosmodm/maria/lyman_alpha/z_2/spectra_H_He_only_z2_250_spectra_16_part.hdf5
# File loaded: /disks/cosmodm/maria/lyman_alpha/z_2/spectra_H_He_only_z2_250_spectra_1_part.hdf5
# File loaded: /disks/cosmodm/maria/lyman_alpha/z_2/spectra_H_He_only_z2_250_spectra_2_part.hdf5
# ...

# %%
optical_depth_z2.shape
# Out:
# (2750, 13559)

# %%
np.save('optical_depth_z2.npy', optical_depth_z2)

# %%
z = 3
data_z3 = load_data(z)
optical_depth_z3 = data_z3.get_optical_depth()
# Out:
# File loaded: /disks/cosmodm/maria/lyman_alpha/z_3/spectra_H_He_only_z3_250_spectra_4_part.hdf5
# File loaded: /disks/cosmodm/maria/lyman_alpha/z_3/spectra_H_He_only_z3_250_spectra_12_part.hdf5
# File loaded: /disks/cosmodm/maria/lyman_alpha/z_3/spectra_H_He_only_z3_250_spectra_17_part.hdf5
# File loaded: /disks/cosmodm/maria/lyman_alpha/z_3/spectra_H_He_only_z3_250_spectra_18_part.hdf5
# File loaded: /disks/cosmodm/maria/lyman_alpha/z_3/spectra_H_He_only_z3_250_spectra_6_part.hdf5
# File loaded: /disks/cosmodm/maria/lyman_alpha/z_3/spectra_H_He_only_z3_250_spectra_5_part.hdf5
# File loaded: /disks/cosmodm/maria/lyman_alpha/z_3/spectra_H_He_only_z3_250_spectra_13_part.hdf5
# File loaded: /disks/cosmodm/maria/lyman_alpha/z_3/spectra_H_He_only_z3_250_spectra_1_part.hdf5
# File loaded: /disks/cosmodm/maria/lyman_alpha/z_3/spectra_H_He_only_z3_250_spectra_9_part.hdf5
# File loaded: /disks/cosmodm/maria/lyman_alpha/z_3/spectra_H_He_only_z3_250_spectra_14_part.hdf5
# ...

# %%
np.save('optical_depth_z3.npy', optical_depth_z3)

# %%
z = 4
optical_depth_z4 = get_optical_depth(z, 50)
np.save('optical_depth_z4_50.npy', optical_depth_z4)
# Out:
# File loaded: /disks/cosmodm/maria/lyman_alpha/z_4/spectra_H_He_only_z4_50_spectra_0_part.hdf5
# File loaded: /disks/cosmodm/maria/lyman_alpha/z_4/spectra_H_He_only_z4_50_spectra_1_part.hdf5
# File loaded: /disks/cosmodm/maria/lyman_alpha/z_4/spectra_H_He_only_z4_50_spectra_2_part.hdf5
# File loaded: /disks/cosmodm/maria/lyman_alpha/z_4/spectra_H_He_only_z4_50_spectra_3_part.hdf5
# File loaded: /disks/cosmodm/maria/lyman_alpha/z_4/spectra_H_He_only_z4_50_spectra_4_part.hdf5
# File loaded: /disks/cosmodm/maria/lyman_alpha/z_4/spectra_H_He_only_z4_50_spectra_5_part.hdf5
# File loaded: /disks/cosmodm/maria/lyman_alpha/z_4/spectra_H_He_only_z4_50_spectra_6_part.hdf5
# File loaded: /disks/cosmodm/maria/lyman_alpha/z_4/spectra_H_He_only_z4_50_spectra_7_part.hdf5
# File loaded: /disks/cosmodm/maria/lyman_alpha/z_4/spectra_H_He_only_z4_50_spectra_8_part.hdf5

# %%
z = 4
optical_depth_z4 = get_optical_depth(z, 250)
np.save('optical_depth_z4_250.npy', optical_depth_z4)
# Out:
# File skipped/corrupted: /disks/cosmodm/maria/lyman_alpha/z_4/spectra_H_He_only_z4_250_spectra_0_part.hdf5
# File skipped/corrupted: /disks/cosmodm/maria/lyman_alpha/z_4/spectra_H_He_only_z4_250_spectra_10_part.hdf5
# File skipped/corrupted: /disks/cosmodm/maria/lyman_alpha/z_4/spectra_H_He_only_z4_250_spectra_11_part.hdf5
# File skipped/corrupted: /disks/cosmodm/maria/lyman_alpha/z_4/spectra_H_He_only_z4_250_spectra_12_part.hdf5
# File skipped/corrupted: /disks/cosmodm/maria/lyman_alpha/z_4/spectra_H_He_only_z4_250_spectra_13_part.hdf5
# File skipped/corrupted: /disks/cosmodm/maria/lyman_alpha/z_4/spectra_H_He_only_z4_250_spectra_14_part.hdf5
# File skipped/corrupted: /disks/cosmodm/maria/lyman_alpha/z_4/spectra_H_He_only_z4_250_spectra_15_part.hdf5
# File skipped/corrupted: /disks/cosmodm/maria/lyman_alpha/z_4/spectra_H_He_only_z4_250_spectra_16_part.hdf5
# File skipped/corrupted: /disks/cosmodm/maria/lyman_alpha/z_4/spectra_H_He_only_z4_250_spectra_17_part.hdf5
# ...

# %%
import matplotlib.pyplot as plt
data = np.load('hydrogen_redshift234_tau/optical_depth_z3.npy')
plt.plot(np.exp(-data[100]))
